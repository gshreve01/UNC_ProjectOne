# %%
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
import requests
import gmaps
import os
import json
from config import gkey

# %%
base_url = "https://maps.googleapis.com/maps/api/place/nearbysearch/json"

params = {
    "location": "35.2274877,-80.8622282", 
    "radius": 50000,
    "type": "bank",
     "key": gkey
}

Banks_info =[]

for bank_dict in bank_data['results']:
    
    try:

        bank_data = response.json()
        bank_name = bank_dict['name']
        bank_lat=bank_dict['geometry']['location']['lat']
        bank_lng=bank_dict['geometry']['location']['lng']
        bank_rating = bank_dict['rating']
        bank_types =bank_dict['types']
        bank_address=bank_dict["vicinity"]
        Banks_info.append({"Bank_Name":bank_name,
                         "Lat":bank_lat,
                         "Lng":bank_lng,
                         "Rating":bank_rating,
                         "Bank_Types":bank_types,
                         "Bank_address":bank_address})
    except KeyError:
              print("Not found")
              pass               

response = requests.get(base_url, params=params)
bank_data = response.json()
print(f'{response}')

print(json.dumps(bank_data['results'], indent=4, sort_keys=True))
# Out:
# Not found
# <Response [200]>
# [
#     {
#         "geometry": {
#             "location": {
#                 "lat": 35.29544600000001,
#                 "lng": -80.7582666
#             },
#             "viewport": {
#                 "northeast": {
#                     "lat": 35.2966422302915,
#                     "lng": -80.75658626970849
#                 },
#                 "southwest": {
#                     "lat": 35.29394426970851,
#                     "lng": -80.7592842302915
#                 }
#             }
#         },
#         "icon": "https://maps.gstatic.com/mapfiles/place_api/icons/bank_dollar-71.png",
#         "id": "b4d7a87439e49c77917b9bc686c418b5dbdaff09",
#         "name": "Woodforest National Bank",
#         "opening_hours": {
#             "open_now": true
#         },
#         "photos": [
#             {
#                 "height": 3120,
#                 "html_attributions": [
# ...

# %%
print(f'{Banks_info}')
len(Banks_info)
# Out:
# [{'Bank_Name': 'Bank of America Financial Center', 'Lat': 35.2274061, 'Lng': -80.8421864, 'Rating': 2.1, 'Bank_Types': ['bank', 'finance', 'point_of_interest', 'establishment'], 'Bank_address': '100 North Tryon Street #170, Charlotte'}, {'Bank_Name': 'State Employees’ Credit Union', 'Lat': 35.2154347, 'Lng': -80.83401200000002, 'Rating': 4.1, 'Bank_Types': ['bank', 'finance', 'point_of_interest', 'establishment'], 'Bank_address': '1130 East 3rd Street, Charlotte'}, {'Bank_Name': 'PNC Bank', 'Lat': 35.2083169, 'Lng': -80.8228768, 'Rating': 3.8, 'Bank_Types': ['bank', 'atm', 'finance', 'point_of_interest', 'establishment'], 'Bank_address': '2000 Randolph Road, Charlotte'}, {'Bank_Name': 'SunTrust', 'Lat': 35.215413, 'Lng': -80.832115, 'Rating': 2.7, 'Bank_Types': ['bank', 'atm', 'finance', 'insurance_agency', 'point_of_interest', 'establishment'], 'Bank_address': '101 South Kings Drive, Charlotte'}, {'Bank_Name': 'Fifth Third Bank & ATM', 'Lat': 35.22868049999999, 'Lng': -80.8416694, '
# ...
